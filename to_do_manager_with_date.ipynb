# %% [markdown]
# # To-Do List Manager
#
# The To-Do List Manager is structured using modular functions that handle task management efficiently. Below is a breakdown of its key components:
#
# ## 🗂 File Handling (tasks_new.txt)
# - **Persistence**: Tasks are stored in a text file to ensure they are not lost when the program exits.
# - **Load Function**: Reads tasks from the file when the program starts.
# - **Save Function**: Writes tasks back to the file after any changes, such as adding or completing tasks.
#
# ## ⚙ Functions for Core Features
#
# ### Adding a Task
# - The user inputs a new task.
# - The task is stored in a list along with its completion status (`completed: False`).
# - The updated task list is saved to the file.
#
# ### Viewing Tasks
# - The program displays all tasks from the list.
# - Each task is marked with ✅ if completed, or ❌ if pending.
#
# ### Marking a Task as Complete
# - The user selects a task number.
# - The task's status is updated to completed (`completed: True`).
# - Changes are saved to the file.
#
# ## 🛠 Error Handling
# - **File Existence Check**: Before reading tasks, the program checks if the task file exists to prevent errors.
# - **Input Validation**: When marking tasks as complete, it validates user input to prevent invalid task selections.
# - **Try-Except Block**: Handles incorrect number inputs when selecting tasks.
#
# ## 🔄 User Interaction (main() Function)
# - The program runs in a loop, displaying a menu-driven interface for user actions.
# - Users can add tasks, view tasks, mark tasks as complete, or exit the program.
# - The program continues running until the user chooses to exit.

# %%
import os
from datetime import datetime

# File to store tasks
TASK_FILE = "tasks_new.txt"

def load_tasks():
    """Load tasks from file."""
    tasks = {}
    if os.path.exists(TASK_FILE):
        with open(TASK_FILE, "r") as file:
            for line in file:
                date, task, status = line.strip().split("|")
                if date not in tasks:
                    tasks[date] = []
                tasks[date].append({"task": task, "completed": status == "True"})
    return tasks

def save_tasks(tasks):
    """Save tasks to file."""
    with open(TASK_FILE, "w") as file:
        for date, tasks_list in tasks.items():
            for task in tasks_list:
                file.write(f"{date}|{task['task']}|{task['completed']}\n")

def add_task(tasks):
    """Add a new task."""
    date = input("Enter the date for the task (YYYY-MM-DD): ")
    try:
        datetime.strptime(date, "%Y-%m-%d")  # Validate date format
    except ValueError:
        print("⚠️ Invalid date format. Please use YYYY-MM-DD.")
        return

    task = input("Enter a new task: ")
    if date not in tasks:
        tasks[date] = []
    tasks[date].append({"task": task, "completed": False})
    save_tasks(tasks)
    print("✅ Task added successfully!")

def view_tasks(tasks):
    """View all tasks for a specific date."""
    date = input("Enter the date to view tasks (YYYY-MM-DD): ")
    if date in tasks:
        print(f"\nTasks for {date}:")
        for i, task in enumerate(tasks[date], start=1):
            status = "✅" if task['completed'] else "❌"
            print(f"{i}. {task['task']} {status}")
    else:
        print("⚠️ No tasks available for this date.")

def mark_complete(tasks):
    """Mark a task as completed."""
    date = input("Enter the date to mark tasks as complete (YYYY-MM-DD): ")
    if date in tasks:
        view_tasks(tasks)
        try:
            task_num = int(input("Enter task number to mark as complete: ")) - 1
            if 0 <= task_num < len(tasks[date]):
                tasks[date][task_num]['completed'] = True
                save_tasks(tasks)
                print("✅ Task marked as completed!")
            else:
                print("⚠️ Invalid task number.")
        except ValueError:
            print("⚠️ Please enter a valid number.")
    else:
        print("⚠️ No tasks available for this date.")

def main():
    """Main function to run the to-do list manager."""
    tasks = load_tasks()
    while True:
        print("\n📌 To-Do List Manager")
        print("1️⃣ Add Task")
        print("2️⃣ View Tasks")
        print("3️⃣ Mark Task Complete")
        print("4️⃣ Exit")
        choice = input("Choose an option: ")
        if choice == "1":
            add_task(tasks)
        elif choice == "2":
            view_tasks(tasks)
        elif choice == "3":
            mark_complete(tasks)
        elif choice == "4":
            print("👋 Exiting... Goodbye!")
            break
        else:
            print("⚠️ Invalid choice. Try again.")

if __name__ == "__main__":
    main()
# Out:
# 📌 To-Do List Manager
# 1️⃣ Add Task
# 2️⃣ View Tasks
# 3️⃣ Mark Task Complete
# 4️⃣ Exit
# Choose an option: 1
# Enter the date for the task (YYYY-MM-DD): 2025/02/02
# ⚠️ Invalid date format. Please use YYYY-MM-DD.
#
# 📌 To-Do List Manager
# 1️⃣ Add Task
# 2️⃣ View Tasks
# 3️⃣ Mark Task Complete
# 4️⃣ Exit
# Choose an option: 2025-02-22
# ⚠️ Invalid choice. Try again.
#
# 📌 To-Do List Manager
# 1️⃣ Add Task
# 2️⃣ View Tasks
# 3️⃣ Mark Task Complete
# 4️⃣ Exit
# Choose an option: 1
# Enter the date for the task (YYYY-MM-DD): 2025-22-22
# ⚠️ Invalid date format. Please use YYYY-MM-DD.
#
# 📌 To-Do List Manager
# 1️⃣ Add Task
# 2️⃣ View Tasks
# 3️⃣ Mark Task Complete
# 4️⃣ Exit
# Choose an option: 2025-02-02
# ⚠️ Invalid choice. Try again.
#
# 📌 To-Do List Manager
# 1️⃣ Add Task
# 2️⃣ View Tasks
# 3️⃣ Mark Task Complete
# 4️⃣ Exit
# Choose an option: 1
# Enter the date for the task (YYYY-MM-DD): 2025-02-02
# Enter a new task: attend classes
# ✅ Task added successfully!
#
# ...
